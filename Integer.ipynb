# %%
L = int(input("Введите число L: "))
met =  L //  100
print(met)#int1
# Out:
# Введите число L: 270
# 2

# %%
M = int(input("Введите число M: "))
ton = M // 1000
print(ton)#int2
# Out:
# Введите число M: 2700
# 2

# %%
Bait = int(input("Введите число Bait: "))
kilb = Bait // 1024
print(kilb)#int3
# Out:
# Введите число Bait: 2048
# 2

# %%
A = int(input("Введите число A: "))
B = int(input("Введите число B: "))
otr = A // B
print(otr)#int4
# Out:
#   File "/tmp/ipykernel_776/363652463.py", line 5
#     (без наложений). Используя операцию деления нацело, найти количество
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
A = int(input("Введите число A: "))
B = int(input("Введите число B: "))
ost = A % B
print(ost)#int5
# Out:
# Введите число A: 6
# Введите число B: 36
# 6

# %%
A = int(input("Введите число A: "))
B = int(input("Введите число B: "))
ost = A % B
otr = A // B
print(ost)
print(otr)#int6

# %%
N = int(input("Введите  двузначное чилсо N: "))
edin = N % 10
des = N // 10
print(edin, des)#int7
# Out:
# Введите  двузначное чилсо N: 20
# 0 2

# %%
N = int(input("Введите  двузначное чилсо N: "))
M = int(input("Введите  двузначное чилсо M: "))
sum = N + M
proizv = N * M
print(sum, proizv)#int8
# Out:
# Введите  двузначное чилсо N: 40
# Введите  двузначное чилсо M: 60
# 100 2400

# %%
N = int(input("Введите  трехзначное чилсо N: "))
eds = N // 100
print(eds)#int9
# Out:
# Введите  трехзначное чилсо N: 473
# 4

# %%
N = int(input("Введите  трехзначное чилсо N: "))
edin = N % 100
des = N // 100
print(edin, des)#int10
# Out:
# Введите  двузначное чилсо N: 472
# 72 4

# %%
N = int(input("Введите  трехзначное чилсо N: "))
M = int(input("Введите  трехзначное чилсо M: "))
sum = N + M
proizv = N * M
print(sum, proizv)#int11
# Out:
# Введите  трехзначное чилсо N: 472
# Введите  трехзначное чилсо M: 467
# 939 220424

# %%
N = int(input("Введите  трехзначное чилсо N: "))
h = N // 100
j = (N // 10) % 10
e = N % 10
vmest = e * 100 + j * 10 + h
print(vmest)#itn12
# Out:
# Введите  трехзначное чилсо N: 167
# 761

# %%
N = int(input("Введите  трехзначное чилсо N: "))
h = N // 100
e = N % 100
vmest = e * 1 + h
print(vmest)#int13
# Out:
# Введите  трехзначное чилсо N: 473
# 77

# %%
N = int(input("Введите  трехзначное чилсо N: "))
h = N // 10
e = N % 10
vmest = e * 100 + h
print(vmest)#int14
# Out:
# Введите  трехзначное чилсо N: 473
# 347
